# %%
# %%javascript
#
# Jupyter.keyboard_manager.command_shortcuts.add_shortcut('r', {
#     help : 'run all cells',
#     help_index : 'zz',
#     handler : function (event) {
#         IPython.notebook.execute_all_cells();
#         return false;
#     }}
# );

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import stdev
from statistics import mean
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from matplotlib import pyplot as plt
from keras import regularizers
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import keras
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
final=pd.read_csv("/Users/sparshagarwal/Desktop/NCSA/Dataframes/Combined/Average_years.csv")
#final=pd.read_csv("/Users/sparshagarwal/Desktop/NCSA/Dataframes/Combined/Individual_years.csv")

# %%
final=final[final["IR"]!=0]

# %%
data=final[final.columns[1:]]

# %%
data=shuffle(data)

# %%
#Cross-validation setup
score_train=[]
score_test=[]
rmse_test=[]
kf = KFold(n_splits=5)
for train_index, test_index in kf.split(data):
    X_train=data.iloc[train_index,1:]
    Y_train=data.iloc[train_index,:1]
    X_test=data.iloc[test_index,1:]
    Y_test=data.iloc[test_index,:1]
    
    model=GradientBoostingRegressor()
    #model=XGBRegressor()
    #model=RandomForestRegressor()
    model.fit(X_train.values, Y_train.values.ravel())
    # Calculating coefficient of determination on training set
    score_train.append(model.score(X_train.values,Y_train.values))
    # Calculating coefficient of determination on testing set
    score_test.append(model.score(X_test.values,Y_test.values))
    #Predicting value on test dataset
    Y_pred=model.predict(X_test.values)
    #Calculating RMSE
    rmse_test.append(np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))

# %%
score_train
# Out:
# [0.958515469200247,
#  0.9548210133435476,
#  0.9577955624351043,
#  0.9514238879410464,
#  0.9506207795027679]

# %%
mean(score_train)
# Out:
# 0.9546353424845426

# %%
score_test
# Out:
# [0.24985603344971552,
#  0.41468136970214575,
#  0.30036034727674754,
#  0.309266860551223,
#  0.6730471289403412]

# %%
mean(score_test)
# Out:
# 0.3894423479840346

# %%
mean(rmse_test)
# Out:
# 0.6213122615141422

# %%
#Splitting dataset into testing and training set
train, test= train_test_split(data, test_size=0.20)
#Separating variables and objective function values
X_train=train.iloc[:,1:]
Y_train=train.iloc[:,:1]
X_test=test.iloc[:,1:]
Y_test=test.iloc[:,:1]

# %%
model=GradientBoostingRegressor()
#model=XGBRegressor()
#model=RandomForestRegressor()

# %%
model.fit(X_train.values, Y_train.values.ravel())
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Calculating coefficient of determination on training set
model.score(X_train.values,Y_train.values)
# Out:
# 0.9512167496019788

# %%
# Calculating coefficient of determination on testing set
model.score(X_test.values,Y_test.values )
# Out:
# 0.12332355339176093

# %%
#Predicting value on test dataset
Y_pred=model.predict(X_test.values)

# %%
#Calculating RMSE
np.sqrt(metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# 0.7822250542950776

# %%
result=pd.DataFrame()
result["Actual"]= list(Y_test.values.ravel())
result["Predicted"]= list(Y_pred)
result
# Out:
#       Actual  Predicted
# 0   0.649201   0.773645
# 1   0.877021   2.570906
# 2   0.194806   0.198683
# 3   0.254578   0.470624
# 4   0.181985   0.493080
# ..       ...        ...
# 68  0.125061   0.142955
# 69  0.077125   0.266546
# 70  0.448515   0.963988
# 71  0.276117   0.190746
# 72  1.151717   1.117575
#
# [73 rows x 2 columns]

# %% [markdown]
# Time series, dummy variables for years (with and without). Copy to Aiman. Remove dependent variables. Upload data on Box.

# %%
data=shuffle(data)

# %%
#Cross -validation setup
score_train=[]
score_test=[]
rmse_test=[]
kf = KFold(n_splits=5)
for train_index, test_index in kf.split(data):
    X_train=data.iloc[train_index,1:].values
    Y_train=data.iloc[train_index,:1].values
    X_test=data.iloc[test_index,1:].values
    Y_test=data.iloc[test_index,:1].values
    
    layer=keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros', moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, beta_constraint=None, gamma_constraint=None)
    layer2=Dense(10, activation="relu", use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)
    #layer2_5=Dense(20, activation="relu", use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)
    #layer3=keras.layers.Dropout(0.1, noise_shape=None, seed=None)
    layer4=Dense(1, activation="sigmoid", use_bias=True, bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)
    model_val = Sequential()  
    model_val.add(layer)
    model_val.add(layer2)
    #model_val.add(layer3)
    #model_val.add(layer2_5)
    model_val.add(layer4)
    #model_val.compile(loss='mean_absolute_error', optimizer='adam',metrics=[coeff_determination])
    model_val.compile(loss='mean_absolute_error', optimizer='adam',metrics=["mae"])
    history=model_val.fit(X_train, Y_train, nb_epoch=500, validation_data=(X_test, Y_test))
    
    Y_pred_train = model_val.predict(X_train).ravel()
    Y_pred_test = model_val.predict(X_test).ravel()
    
    # Calculating coefficient of determination on training set
    score_train.append(r2_score(Y_train.ravel(), Y_pred_train))
    # Calculating coefficient of determination on testing set
    score_test.append(r2_score(Y_test.ravel(), Y_pred_test))
    #Calculating RMSE
    rmse_test.append(np.sqrt(metrics.mean_squared_error(Y_test.ravel(), Y_pred_test)))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 289 samples, validate on 73 samples
# Epoch 1/500
# 289/289 [==============================] - 0s 979us/step - loss: 0.5614 - mae: 0.5614 - val_loss: 0.6151 - val_mae: 0.6151
# Epoch 2/500
# 289/289 [==============================] - 0s 56us/step - loss: 0.5531 - mae: 0.5531 - val_loss: 0.6151 - val_mae: 0.6151
# Epoch 3/500
# 289/289 [==============================] - 0s 59us/step - loss: 0.5485 - mae: 0.5485 - val_loss: 0.6151 - val_mae: 0.6151
# Epoch 4/500
# 289/289 [==============================] - 0s 75us/step - loss: 0.5358 - mae: 0.5358 - val_loss: 0.6149 - val_mae: 0.6149
# Epoch 5/500
# 289/289 [==============================] - 0s 73us/step - loss: 0.5310 - mae: 0.5310 - val_loss: 0.6144 - val_mae: 0.6144
# Epoch 6/500
# ...

# %%
mean(score_train)
# Out:
# 0.23384461135157739

# %%
mean(score_test)
# Out:
# 0.15187456176042238

# %%
mean(rmse_test)
# Out:
# 0.7535374252670503

# %%
score_test
# Out:
# [0.16760620368732893,
#  0.19382634992898495,
#  0.10504593968960796,
#  0.10537773666579642,
#  0.18751657883039363]

# %%
mean_absolute_error(Y_train.ravel(),Y_pred_train)
# Out:
# 0.35824061628342513

# %%
mean_absolute_error(Y_test.ravel(),Y_pred_test)
# Out:
# 0.37659309807960345

# %%
layer=keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros', moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, beta_constraint=None, gamma_constraint=None)

# %%
layer2=Dense(10, activation="relu", use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)

# %%
#layer2_5=Dense(20, activation="relu", use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)

# %%
#layer3=keras.layers.Dropout(0.1, noise_shape=None, seed=None)

# %%
layer4=Dense(1, activation="sigmoid", use_bias=True, bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)

# %%
model_val = Sequential()  
model_val.add(layer)
model_val.add(layer2)
#model_val.add(layer3)
#model_val.add(layer2_5)
model_val.add(layer4)

# %%
model_val.compile(loss='mean_absolute_error', optimizer='adam',metrics=[coeff_determination])

# %%
history=model_val.fit(X_train, Y_train, nb_epoch=500, validation_data=(X_test, Y_test))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Train on 325 samples, validate on 37 samples
# Epoch 1/500
# 325/325 [==============================] - 0s 897us/step - loss: 0.5165 - coeff_determination: -0.0468 - val_loss: 0.7254 - val_coeff_determination: -0.9717
# Epoch 2/500
# 325/325 [==============================] - 0s 58us/step - loss: 0.5018 - coeff_determination: -0.0932 - val_loss: 0.7225 - val_coeff_determination: -0.9594
# Epoch 3/500
# 325/325 [==============================] - 0s 70us/step - loss: 0.4913 - coeff_determination: 0.0524 - val_loss: 0.7164 - val_coeff_determination: -0.9339
# Epoch 4/500
# 325/325 [==============================] - 0s 66us/step - loss: 0.4855 - coeff_determination: -0.0183 - val_loss: 0.7051 - val_coeff_determination: -0.8873
# Epoch 5/500
# ...

# %%
Y_pred_train = model_val.predict(X_train).ravel()

# %%
Y_pred_test = model_val.predict(X_test).ravel()

# %%
result=pd.DataFrame()
result["Actual"]= list(Y_train.ravel())
result["Predicted"]= list(Y_pred_train)
result
# Out:
#        Actual  Predicted
# 0    0.131379   0.092947
# 1    0.842615   0.778697
# 2    0.113509   0.158730
# 3    0.165925   0.516278
# 4    0.096612   0.082583
# ..        ...        ...
# 285  0.077125   0.278362
# 286  0.505144   0.368684
# 287  0.128594   0.230458
# 288  0.123537   0.280622
# 289  0.957708   0.686298
#
# [290 rows x 2 columns]

# %%
result=pd.DataFrame()
result["Actual"]= list(Y_test.ravel())
result["Predicted"]= list(Y_pred_test)
result
# Out:
#       Actual  Predicted
# 0   0.491702   0.270684
# 1   0.321598   0.598359
# 2   0.230307   0.850801
# 3   0.223403   0.289925
# 4   0.117015   0.723367
# ..       ...        ...
# 67  0.398788   0.293679
# 68  0.190581   0.040185
# 69  0.890842   0.697932
# 70  0.185904   0.243643
# 71  0.045385   0.459163
#
# [72 rows x 2 columns]

# %%
r2_score(Y_train.ravel(), Y_pred_train)
# Out:
# 0.23167862790161164

# %%
r2_score(Y_test.ravel(), Y_pred_test)
# Out:
# 0.40682605755923107
