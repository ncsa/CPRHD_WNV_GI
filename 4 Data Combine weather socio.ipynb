# %%
import numpy as np
import pandas as pd

# %%
final_data_frame=pd.read_csv(r'C:\Users\Rohan\Desktop\export_dataframe.csv')

# %%
final_data_frame
# Out:
#      Unnamed: 0  GEO.id2  HC01_EST_VC33  HC01_EST_VC35_x  HC01_EST_VC35_y  \
# 0             0     1001           36.0             36.2             36.4
# 1             1     1003           41.0             41.0             41.4
# 2             7     1015           38.1             38.1             38.4
# 3            16     1033           40.9             41.6             41.7
# 4            22     1045           34.9             35.8             36.0
# 5            25     1051           36.8             37.3             37.6
# 6            27     1055           39.3             40.0             39.9
# 7            34     1069           38.2             38.0             38.2
# 8            36     1073           36.8             37.0             37.0
# 9            38     1077           39.6             39.7             40.3
# 10           40     1081           26.9             28.8             28.9
# 11           41     1083           38.0             38.5             38.7
# ...

# %%
final_data_frame.columns
# Out:
# Index(['Unnamed: 0', 'GEO.id2', 'HC01_EST_VC33', 'HC01_EST_VC35_x',
#        'HC01_EST_VC35_y', 'HC01_EST_VC35_x.1', 'HC01_EST_VC35_y.1',
#        'HC01_EST_VC35_x.2', 'HC01_EST_VC35_y.2', 'HC01_EST_VC35',
#        ...
#        'humidity_entropy_2006', 'humidity_entropy_2007',
#        'humidity_entropy_2008', 'humidity_entropy_2009',
#        'humidity_entropy_2010', 'humidity_entropy_2011',
#        'humidity_entropy_2012', 'humidity_entropy_2013',
#        'humidity_entropy_2014', 'humidity_entropy_2015'],
#       dtype='object', length=187)

# %%
trial=final_data_frame

# %%
final_data_frame.columns=['unnamed','GEOID','Median_Age_2009','Median_Age_2010','Median_Age_2011','Median_Age_2012','Median_Age_2013','Median_Age_2014','Median_Age_2015','Median_Age_2016','Median_Age_2017','Median_Family_Income($)_2009','Median_Family_Income($)_2010','Median_Family_Income($)_2011','Median_Family_Income($)_2012','Median_Family_Income($)_2013','Median_Family_Income($)_2014','Median_Family_Income($)_2015','Median_Family_Income($)_2016','Median_Family_Income($)_2017','Percent_below_poverty_level_2012','Percent_below_poverty_level_2013','Percent_below_poverty_level_2014','Percent_below_poverty_level_2015','Percent_below_poverty_level_2016','Percent_below_poverty_level_2017','Percent_White_2010','Percent_Af_Am_2010','Percent_Asian_2010','Percent_White_2011','Percent_Af_Am_2011','Percent_Asian_2011','Percent_White_2012','Percent_Af_Am_2012','Percent_Asian_2012','Percent_White_2013','Percent_Af_Am_2013','Percent_Asian_2013','Percent_White_2014','Percent_Af_Am_2014','Percent_Asian_2014','Percent_White_2015','Percent_Af_Am_2015','Percent_Asian_2015','Percent_White_2016','Percent_Af_Am_2016','Percent_Asian_2016','Percent_White_2017','Percent_Af_Am_2017','Percent_Asian_2017','index','air_temp_sfc_1999','air_temp_sfc_2000','air_temp_sfc_2001','air_temp_sfc_2002','air_temp_sfc_2003','air_temp_sfc_2004','air_temp_sfc_2005','air_temp_sfc_2006','air_temp_sfc_2007','air_temp_sfc_2008','air_temp_sfc_2009','air_temp_sfc_2010','air_temp_sfc_2011','air_temp_sfc_2012','air_temp_sfc_2013','air_temp_sfc_2014','air_temp_sfc_2015','air_temp_sfc_entropy_1999','air_temp_sfc_entropy_2000','air_temp_sfc_entropy_2001','air_temp_sfc_entropy_2002','air_temp_sfc_entropy_2003','air_temp_sfc_entropy_2004','air_temp_sfc_entropy_2005','air_temp_sfc_entropy_2006','air_temp_sfc_entropy_2007','air_temp_sfc_entropy_2008','air_temp_sfc_entropy_2009','air_temp_sfc_entropy_2010','air_temp_sfc_entropy_2011','air_temp_sfc_entropy_2012','air_temp_sfc_entropy_2013','air_temp_sfc_entropy_2014','air_temp_sfc_entropy_2015','air_temp_2m_1999','air_temp_2m_2000','air_temp_2m_2001','air_temp_2m_2002','air_temp_2m_2003','air_temp_2m_2004','air_temp_2m_2005','air_temp_2m_2006','air_temp_2m_2007','air_temp_2m_2008','air_temp_2m_2009','air_temp_2m_2010','air_temp_2m_2011','air_temp_2m_2012','air_temp_2m_2013','air_temp_2m_2014','air_temp_2m_2015','air_temp_2m_entropy_1999','air_temp_2m_entropy_2000','air_temp_2m_entropy_2001','air_temp_2m_entropy_2002','air_temp_2m_entropy_2003','air_temp_2m_entropy_2004','air_temp_2m_entropy_2005','air_temp_2m_entropy_2006','air_temp_2m_entropy_2007','air_temp_2m_entropy_2008','air_temp_2m_entropy_2009','air_temp_2m_entropy_2010','air_temp_2m_entropy_2011','air_temp_2m_entropy_2012','air_temp_2m_entropy_2013','air_temp_2m_entropy_2014','air_temp_2m_entropy_2015','precipitation_1999','precipitation_2000','precipitation_2001','precipitation_2002','precipitation_2003','precipitation_2004','precipitation_2005','precipitation_2006','precipitation_2007','precipitation_2008','precipitation_2009','precipitation_2010','precipitation_2011','precipitation_2012','precipitation_2013','precipitation_2014','precipitation_2015','precipitation_entropy_1999','precipitation_entropy_2000','precipitation_entropy_2001','precipitation_entropy_2002','precipitation_entropy_2003','precipitation_entropy_2004','precipitation_entropy_2005','precipitation_entropy_2006','precipitation_entropy_2007','precipitation_entropy_2008','precipitation_entropy_2009','precipitation_entropy_2010','precipitation_entropy_2011','precipitation_entropy_2012','precipitation_entropy_2013','precipitation_entropy_2014','precipitation_entropy_2015','humidity_1999','humidity_2000','humidity_2001','humidity_2002','humidity_2003','humidity_2004','humidity_2005','humidity_2006','humidity_2007','humidity_2008','humidity_2009','humidity_2010','humidity_2011','humidity_2012','humidity_2013','humidity_2014','humidity_2015','humidity_entropy_1999','humidity_entropy_2000','humidity_entropy_2001','humidity_entropy_2002','humidity_entropy_2003','humidity_entropy_2004','humidity_entropy_2005','humidity_entropy_2006','humidity_entropy_2007','humidity_entropy_2008','humidity_entropy_2009','humidity_entropy_2010','humidity_entropy_2011','humidity_entropy_2012','humidity_entropy_2013','humidity_entropy_2014','humidity_entropy_2015']

# %%
final_data_frame.head()
# Out:
#    unnamed  GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0        0   1001             36.0             36.2             36.4
# 1        1   1003             41.0             41.0             41.4
# 2        7   1015             38.1             38.1             38.4
# 3       16   1033             40.9             41.6             41.7
# 4       22   1045             34.9             35.8             36.0
#
#    Median_Age_2012  Median_Age_2013  Median_Age_2014  Median_Age_2015  \
# 0             37.0             37.5             37.9             37.7
# 1             41.2             41.5             41.8             42.2
# 2             38.7             38.7             38.8             39.1
# 3             41.7             41.7             42.3             42.2
# 4             36.0             36.1             36.6             36.8
#
#    Median_Age_2016  ...  humidity_entropy_2006  humidity_entropy_2007  \
# ...

# %%
incidence=pd.read_csv(r'C:\Users\Rohan\Downloads\Incidence.csv')

# %%
incidence
# Out:
#       Unnamed: 0  Select_County  Years_with_NI  MEAN_ANNUAL_IR_ESTAB  GEOID10  \
# 0              0              1              1              0.000000     1001
# 1              1              1              4              0.267338     1003
# 2              2              0              1              0.000000     1005
# 3              3              0              1              0.000000     1007
# 4              4              0              0              0.000000     1009
# 5              5              0              0              0.000000     1011
# 6              6              0              1              0.000000     1013
# 7              7              1              1              0.000000     1015
# 8              8              0              2              0.220745     1017
# 9              9              0              0              0.000000     1019
# 10            10              0              0              0.000000     1021
# ...

# %%
incidence=incidence[incidence['Select_County']==1]

# %%
incidence
# Out:
#       Unnamed: 0  Select_County  Years_with_NI  MEAN_ANNUAL_IR_ESTAB  GEOID10  \
# 0              0              1              1              0.000000     1001
# 1              1              1              4              0.267338     1003
# 7              7              1              1              0.000000     1015
# 16            16              1              0              0.000000     1033
# 22            22              1              1              0.000000     1045
# 25            25              1              1              0.000000     1051
# 27            27              1              1              0.000000     1055
# 34            34              1              4              0.460573     1069
# 36            36              1              7              0.336928     1073
# 38            38              1              1              0.000000     1077
# 40            40              1              0              0.000000     1081
# ...

# %%
new=pd.DataFrame(incidence['linear_weighted_after_1st_year'])

# %%
new
# Out:
#       linear_weighted_after_1st_year
# 0                           0.000000
# 1                           0.330975
# 7                           0.000000
# 16                          0.000000
# 22                          0.000000
# 25                          0.000000
# 27                          0.000000
# 34                          0.493437
# 36                          0.236220
# 38                          0.000000
# 40                          0.000000
# 41                          0.000000
# 44                          0.032059
# 48                          0.386611
# 50                          0.685139
# 51                          0.000000
# 56                          0.000000
# 57                          0.000000
# 58                          0.057466
# 60                          0.235218
# 62                          0.296577
# 68                          0.097559
# 69                          0.419641
# 74                          1.219104
# ...

# %%
new.columns=['Mean_after_1st_incidence']

# %%
merge=[final_data_frame,new]

# %%
Data_Frame=pd.concat(merge,axis=1)

# %%
Data_Frame
# Out:
#       unnamed   GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0         0.0  1001.0             36.0             36.2             36.4
# 1         1.0  1003.0             41.0             41.0             41.4
# 2         7.0  1015.0             38.1             38.1             38.4
# 3        16.0  1033.0             40.9             41.6             41.7
# 4        22.0  1045.0             34.9             35.8             36.0
# 5        25.0  1051.0             36.8             37.3             37.6
# 6        27.0  1055.0             39.3             40.0             39.9
# 7        34.0  1069.0             38.2             38.0             38.2
# 8        36.0  1073.0             36.8             37.0             37.0
# 9        38.0  1077.0             39.6             39.7             40.3
# 10       40.0  1081.0             26.9             28.8             28.9
# 11       41.0  1083.0             38.0             38.5             38.7
# ...

# %%
final_data_frame
# Out:
#      unnamed  GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0          0   1001             36.0             36.2             36.4
# 1          1   1003             41.0             41.0             41.4
# 2          7   1015             38.1             38.1             38.4
# 3         16   1033             40.9             41.6             41.7
# 4         22   1045             34.9             35.8             36.0
# 5         25   1051             36.8             37.3             37.6
# 6         27   1055             39.3             40.0             39.9
# 7         34   1069             38.2             38.0             38.2
# 8         36   1073             36.8             37.0             37.0
# 9         38   1077             39.6             39.7             40.3
# 10        40   1081             26.9             28.8             28.9
# 11        41   1083             38.0             38.5             38.7
# ...

# %%
new
# Out:
#       Mean_after_1st_incidence
# 0                     0.000000
# 1                     0.330975
# 7                     0.000000
# 16                    0.000000
# 22                    0.000000
# 25                    0.000000
# 27                    0.000000
# 34                    0.493437
# 36                    0.236220
# 38                    0.000000
# 40                    0.000000
# 41                    0.000000
# 44                    0.032059
# 48                    0.386611
# 50                    0.685139
# 51                    0.000000
# 56                    0.000000
# 57                    0.000000
# 58                    0.057466
# 60                    0.235218
# 62                    0.296577
# 68                    0.097559
# 69                    0.419641
# 74                    1.219104
# 75                    0.188140
# 77                    1.096779
# 78                    1.016164
# 80                    0.138633
# 81                    0.008473
# ...

# %%
trial=final_data_frame

# %%
trial.join(new)
# Out:
#      unnamed  GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0          0   1001             36.0             36.2             36.4
# 1          1   1003             41.0             41.0             41.4
# 2          7   1015             38.1             38.1             38.4
# 3         16   1033             40.9             41.6             41.7
# 4         22   1045             34.9             35.8             36.0
# 5         25   1051             36.8             37.3             37.6
# 6         27   1055             39.3             40.0             39.9
# 7         34   1069             38.2             38.0             38.2
# 8         36   1073             36.8             37.0             37.0
# 9         38   1077             39.6             39.7             40.3
# 10        40   1081             26.9             28.8             28.9
# 11        41   1083             38.0             38.5             38.7
# ...

# %%
final_data_frame.drop(columns=['unnamed'])
# Out:
#      GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0     1001             36.0             36.2             36.4
# 1     1003             41.0             41.0             41.4
# 2     1015             38.1             38.1             38.4
# 3     1033             40.9             41.6             41.7
# 4     1045             34.9             35.8             36.0
# 5     1051             36.8             37.3             37.6
# 6     1055             39.3             40.0             39.9
# 7     1069             38.2             38.0             38.2
# 8     1073             36.8             37.0             37.0
# 9     1077             39.6             39.7             40.3
# 10    1081             26.9             28.8             28.9
# 11    1083             38.0             38.5             38.7
# 12    1089             37.1             37.1             37.1
# 13    1097             35.3             36.3             36.4
# ...

# %%
final_data_frame.drop(columns=['unnamed','index','Median_Age_2016','Median_Age_2017','Median_Family_Income($)_2016','Median_Family_Income($)_2017','Percent_below_poverty_level_2016','Percent_below_poverty_level_2017','Percent_White_2016','Percent_Af_Am_2016','Percent_Asian_2016','Percent_White_2017','Percent_Af_Am_2017','Percent_Asian_2017'],inplace=True)

# %%
final_data_frame
# Out:
#      GEOID  Median_Age_2009  Median_Age_2010  Median_Age_2011  \
# 0     1001             36.0             36.2             36.4
# 1     1003             41.0             41.0             41.4
# 2     1015             38.1             38.1             38.4
# 3     1033             40.9             41.6             41.7
# 4     1045             34.9             35.8             36.0
# 5     1051             36.8             37.3             37.6
# 6     1055             39.3             40.0             39.9
# 7     1069             38.2             38.0             38.2
# 8     1073             36.8             37.0             37.0
# 9     1077             39.6             39.7             40.3
# 10    1081             26.9             28.8             28.9
# 11    1083             38.0             38.5             38.7
# 12    1089             37.1             37.1             37.1
# 13    1097             35.3             36.3             36.4
# ...

# %%
#export_csv = final_data_frame.to_csv (r'C:\Users\Rohan\Desktop\Final_Data_Explanatory.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
#export_csv = new.to_csv (r'C:\Users\Rohan\Desktop\Final_Data_Response.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
incidence
# Out:
#       Unnamed: 0  Select_County  Years_with_NI  MEAN_ANNUAL_IR_ESTAB  GEOID10  \
# 0              0              1              1              0.000000     1001
# 1              1              1              4              0.267338     1003
# 2              2              0              1              0.000000     1005
# 3              3              0              1              0.000000     1007
# 4              4              0              0              0.000000     1009
# 5              5              0              0              0.000000     1011
# 6              6              0              1              0.000000     1013
# 7              7              1              1              0.000000     1015
# 8              8              0              2              0.220745     1017
# 9              9              0              0              0.000000     1019
# 10            10              0              0              0.000000     1021
# ...

# %%
new2=incidence[incidence['Select_County']==1]

# %%
new2=new2[['GEOID10','linear_weighted_after_1st_year']]

# %%
new2
# Out:
#       GEOID10  linear_weighted_after_1st_year
# 0        1001                        0.000000
# 1        1003                        0.330975
# 7        1015                        0.000000
# 16       1033                        0.000000
# 22       1045                        0.000000
# 25       1051                        0.000000
# 27       1055                        0.000000
# 34       1069                        0.493437
# 36       1073                        0.236220
# 38       1077                        0.000000
# 40       1081                        0.000000
# 41       1083                        0.000000
# 44       1089                        0.032059
# 48       1097                        0.386611
# 50       1101                        0.685139
# 51       1103                        0.000000
# 56       1113                        0.000000
# 57       1115                        0.000000
# 58       1117                        0.057466
# ...

# %%
export=pd.read_csv(r'C:\Users\Rohan\Desktop\export.csv')

# %%
export
# Out:
#      GEOID10  NI_IR_1999  NI_IR_2000  NI_IR_2001  NI_IR_2002  NI_IR_2003  \
# 0       1001         0.0         0.0     0.00000    2.178222    0.000000
# 1       1003         0.0         0.0     0.00000    0.000000    2.640107
# 2       1015         0.0         0.0     0.00000    0.000000    0.887272
# 3       1033         0.0         0.0     0.00000    0.000000    0.000000
# 4       1045         0.0         0.0     0.00000    4.050797    0.000000
# 5       1051         0.0         0.0     0.00000    0.000000    0.000000
# 6       1055         0.0         0.0     0.00000    0.970987    0.000000
# 7       1069         0.0         0.0     0.00000    1.111852    1.095038
# 8       1073         0.0         0.0     0.30294    1.064610    1.064618
# 9       1077         0.0         0.0     0.00000    0.000000    0.000000
# 10      1081         0.0         0.0     0.00000    0.000000    0.000000
# 11      1083         0.0         0.0     0.00000    0.000000    0.000000
# ...

# %%
new3=new2.merge(export,on='GEOID10',how='inner')

# %%
new3
# Out:
#      GEOID10  linear_weighted_after_1st_year  NI_IR_1999  NI_IR_2000  \
# 0       1001                        0.000000         0.0         0.0
# 1       1003                        0.330975         0.0         0.0
# 2       1015                        0.000000         0.0         0.0
# 3       1033                        0.000000         0.0         0.0
# 4       1045                        0.000000         0.0         0.0
# 5       1051                        0.000000         0.0         0.0
# 6       1055                        0.000000         0.0         0.0
# 7       1069                        0.493437         0.0         0.0
# 8       1073                        0.236220         0.0         0.0
# 9       1077                        0.000000         0.0         0.0
# 10      1081                        0.000000         0.0         0.0
# 11      1083                        0.000000         0.0         0.0
# 12      1089                        0.032059         0.0         0.0
# ...

# %%
new3.rename(columns={"linear_weighted_after_1st_year":"Incidence_after_1st_Year"},inplace= True)

# %%
new3
# Out:
#      GEOID10  Incidence_after_1st_Year  NI_IR_1999  NI_IR_2000  NI_IR_2001  \
# 0       1001                  0.000000         0.0         0.0     0.00000
# 1       1003                  0.330975         0.0         0.0     0.00000
# 2       1015                  0.000000         0.0         0.0     0.00000
# 3       1033                  0.000000         0.0         0.0     0.00000
# 4       1045                  0.000000         0.0         0.0     0.00000
# 5       1051                  0.000000         0.0         0.0     0.00000
# 6       1055                  0.000000         0.0         0.0     0.00000
# 7       1069                  0.493437         0.0         0.0     0.00000
# 8       1073                  0.236220         0.0         0.0     0.30294
# 9       1077                  0.000000         0.0         0.0     0.00000
# 10      1081                  0.000000         0.0         0.0     0.00000
# ...

# %%
export_csv = new3.to_csv (r'C:\Users\Rohan\Desktop\Final_Data_Frame_Response.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
